# %% [markdown]
# # Part D. Increase the number of hidden layers
# Repeat part B but use a neural network with the following instead:
#
# Three hidden layers, each of 10 nodes and ReLU activation function.

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import keras
from keras.models import Sequential
from keras.layers import Dense

# %%
data = pd.read_csv('https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0101EN/labs/data/concrete_data.csv')
data.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  ...  Fine Aggregate  Age  Strength
# 0   540.0                 0.0      0.0  ...           676.0   28     79.99
# 1   540.0                 0.0      0.0  ...           676.0   28     61.89
# 2   332.5               142.5      0.0  ...           594.0  270     40.27
# 3   332.5               142.5      0.0  ...           594.0  365     41.05
# 4   198.6               132.4      0.0  ...           825.5  360     44.30
#
# [5 rows x 9 columns]

# %%
def build_baseline_model():
  X = data.drop('Strength', axis=1)
  X_norm = (X - X.mean()) / X.std()
  y = data['Strength']
  X_train, X_test, y_train, y_test = train_test_split(X_norm, y, test_size=0.3)

  model = Sequential()
  model.add(Dense(10, activation='relu', input_shape=(X.shape[1], )))
  model.add(Dense(10, activation='relu'))
  model.add(Dense(10, activation='relu'))
  model.add(Dense(1))
  model.compile(optimizer='adam', loss='mean_squared_error')
  model.fit(X_train, y_train, validation_split=0.3, epochs=50, verbose=2)

  y_pred = model.predict(X_test)
  mse = mean_squared_error(y_test, y_pred)
  
  return mse

# %%
mse_list = []
for i in range(50):
  mse_list.append(build_baseline_model())
mse_list
# Out:
# Streaming output truncated to the last 5000 lines.
# Epoch 1/50
# 16/16 - 1s - loss: 1613.3943 - val_loss: 1573.7900
# Epoch 2/50
# 16/16 - 0s - loss: 1593.9852 - val_loss: 1554.6127
# Epoch 3/50
# 16/16 - 0s - loss: 1574.5156 - val_loss: 1533.7705
# Epoch 4/50
# 16/16 - 0s - loss: 1552.9224 - val_loss: 1509.6429
# Epoch 5/50
# 16/16 - 0s - loss: 1526.9349 - val_loss: 1481.3477
# Epoch 6/50
# 16/16 - 0s - loss: 1495.6392 - val_loss: 1446.6982
# Epoch 7/50
# 16/16 - 0s - loss: 1456.9712 - val_loss: 1403.4196
# Epoch 8/50
# 16/16 - 0s - loss: 1408.1482 - val_loss: 1349.9036
# Epoch 9/50
# 16/16 - 0s - loss: 1347.9108 - val_loss: 1285.5135
# Epoch 10/50
# 16/16 - 0s - loss: 1275.5281 - val_loss: 1207.4830
# Epoch 11/50
# 16/16 - 0s - loss: 1189.1660 - val_loss: 1114.5446
# Epoch 12/50
# 16/16 - 0s - loss: 1087.8999 - val_loss: 1008.2591
# Epoch 13/50
# 16/16 - 0s - loss: 974.1093 - val_loss: 890.5379
# Epoch 14/50
# 16/16 - 0s - loss: 849.9556 - val_loss: 762.9479
# Epoch 15/50
# ...

# %% [markdown]
# How does the mean of the mean squared errors compare to that from Step B?

# %%
mean_mse = np.mean(mse_list)
std_mse = np.std(mse_list)
print("The mean of mean squred errors of Step D is: {}".format(mean_mse))
print("The standard deviation of mean squred erros of Step D is: {}".format(std_mse))
# Out:
# The mean of mean squred errors of Step D is: 149.18375032985676
# The standard deviation of mean squred erros of Step D is: 15.397254991788246

# %%
print("The mean of mean squred errors of Step B is: 667.9651366816877")
print("The standard deviation of mean squred erros of Step B is: 117.93472949476589")
# Out:
# The mean of mean squred errors of Step B is: 667.9651366816877
# The standard deviation of mean squred erros of Step B is: 117.93472949476589

# %%
print("The mean of the mean squared error DECREASED comparing to Step B")
# Out:
# The mean of the mean squared error DECREASED comparing to Step B
